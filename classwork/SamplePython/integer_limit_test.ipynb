# %% [markdown]
# 02/05/2026

# %%
i = 1
i += 1
print(i)

j = 2147483647
k = j + 1
print(j, k)
# Out:
# 2
# 2147483647 2147483648

# %%
l = 1

print(l+2**-53) # =1
# therefore:
print(l+2**-52) # is machine epsilon value
# Out:
# 1.0
# 1.0000000000000002
