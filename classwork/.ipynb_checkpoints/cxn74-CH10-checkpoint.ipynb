# %% [markdown]
# 03/03/2026

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
# Challenge A

# %%
x = np.random.uniform(0, 10, 10)
y = np.random.uniform(0, 10, 10)
x.sort()

d = np.vstack([x, np.ones(len(x))]).T

m, c = np.linalg.lstsq(d, y, rcond=None)[0]

y1 = m*x + c

plt.scatter(x, y)
plt.plot(x, y1)
plt.show()

# %%
# Mean Squared Error (MSE)
mse_leastsquares = np.mean((y - y1)**2)
print(f'Mean Squared Error: {mse_leastsquares:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y1)**2)
r_squared_leastsquares = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared_leastsquares:.4f}')
# Out:
# Mean Squared Error: 9.3897
# R-squared: 0.2138

# %%
degree = 3 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Print the polynomial coefficients
print("Polynomial Coefficients: ", coefficients)

# Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)

# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# Polynomial Coefficients:  [-0.09420472  1.40747177 -5.9061132  10.10802148]

# %%
# Mean Squared Error (MSE)
mse_cubic = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse_cubic:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared_cubic = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared_cubic:.4f}')
# Out:
# Mean Squared Error: 6.3148
# R-squared: 0.4712

# %%
if ((mse_leastsquares<mse_cubic) & (r_squared_leastsquares>r_squared_cubic)):
    print("Lower MSE =", mse_leastsquares, "\nHigher R-Squared Value =", r_squared_leastsquares)
    print("The Linear Least Squares method is a better fit because the MSE is closer to 0 and the R-Squared value is closer to 1 compared to the Polynomial fit.")
else:
    print("Lower MSE =", mse_cubic, "\nHigher R-Squared Value =", r_squared_cubic)
    print("The Polynomial fit method (cubic) is a better fit because the MSE is closer to 0 and the R-Squared value is closer to 1 compared to the Linear fit.")
# Out:
# Lower MSE = 6.314775987247443
# Higher R-Squared Value = 0.471246505576123
# The Polynomial fit method (cubic) is a better fit because the MSE is closer to 0 and the R-Squared value is closer to 1 compared to the Linear fit.

# %%
# Challenge B

# %%
degree = 4 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)

# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error: 5.6270
# R-squared: 0.5288

# %%
degree = 5 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)

# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error: 3.9165
# R-squared: 0.6721

# %%
degree = 8 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)

# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error: 0.7175
# R-squared: 0.9399

# %%
degree = 9 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)

# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error: 0.0000
# R-squared: 1.0000

# %%
degree = 2 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)

# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error: 9.3831
# R-squared: 0.2143

# %%
degree = 1 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)

# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse_cubic = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse_cubic:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared_cubic = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared_cubic:.4f}')
# Out:
# Mean Squared Error: 9.3897
# R-squared: 0.2138

# %%
degree = 0.9 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)

# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error: 11.9428
# R-squared: -0.0000

# %%
# Challenge C

degree = 3
V = np.vander(x, N=degree+1, increasing=True)

print(V)

# V.T * V
VT_V = np.dot(V.T, V)
# V.T * y
VT_y = np.dot(V.T, y)
# Solve for a (coefficients)
coefficients = np.linalg.solve(VT_V, VT_y)

polynomial = np.poly1d(coefficients[::-1])

y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# [[1.00000000e+00 9.99438742e-02 9.98877799e-03 9.98317171e-04]
#  [1.00000000e+00 9.85997254e-01 9.72190586e-01 9.58577248e-01]
#  [1.00000000e+00 1.39591040e+00 1.94856584e+00 2.72002332e+00]
#  [1.00000000e+00 1.44754036e+00 2.09537311e+00 3.03313715e+00]
#  [1.00000000e+00 4.26770020e+00 1.82132650e+01 7.77287544e+01]
#  [1.00000000e+00 4.68322337e+00 2.19325812e+01 1.02715177e+02]
#  [1.00000000e+00 5.42795763e+00 2.94627240e+01 1.59922418e+02]
#  [1.00000000e+00 6.45394236e+00 4.16533720e+01 2.68828462e+02]
#  [1.00000000e+00 7.93669447e+00 6.29911191e+01 4.99941267e+02]
#  [1.00000000e+00 9.68714704e+00 9.38408177e+01 9.09049799e+02]]
# Mean Squared Error: 6.3148
# R-squared: 0.4712

# %%
degree = 4
V = np.vander(x, N=degree+1, increasing=True)

print(V)

# V.T * V
VT_V = np.dot(V.T, V)
# V.T * y
VT_y = np.dot(V.T, y)
# Solve for a (coefficients)
coefficients = np.linalg.solve(VT_V, VT_y)

polynomial = np.poly1d(coefficients[::-1])

y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# [[1.00000000e+00 9.99438742e-02 9.98877799e-03 9.98317171e-04
#   9.97756858e-05]
#  [1.00000000e+00 9.85997254e-01 9.72190586e-01 9.58577248e-01
#   9.45154535e-01]
#  [1.00000000e+00 1.39591040e+00 1.94856584e+00 2.72002332e+00
#   3.79690883e+00]
#  [1.00000000e+00 1.44754036e+00 2.09537311e+00 3.03313715e+00
#   4.39058845e+00]
#  [1.00000000e+00 4.26770020e+00 1.82132650e+01 7.77287544e+01
#   3.31723021e+02]
#  [1.00000000e+00 4.68322337e+00 2.19325812e+01 1.02715177e+02
#   4.81038116e+02]
#  [1.00000000e+00 5.42795763e+00 2.94627240e+01 1.59922418e+02
#   8.68052107e+02]
#  [1.00000000e+00 6.45394236e+00 4.16533720e+01 2.68828462e+02
#   1.73500340e+03]
#  [1.00000000e+00 7.93669447e+00 6.29911191e+01 4.99941267e+02
#   3.96788109e+03]
#  [1.00000000e+00 9.68714704e+00 9.38408177e+01 9.09049799e+02
#   8.80609907e+03]]
# Mean Squared Error: 5.6270
# R-squared: 0.5288

# %%
degree = 5
V = np.vander(x, N=degree+1, increasing=True)

print(V)

# V.T * V
VT_V = np.dot(V.T, V)
# V.T * y
VT_y = np.dot(V.T, y)
# Solve for a (coefficients)
coefficients = np.linalg.solve(VT_V, VT_y)

polynomial = np.poly1d(coefficients[::-1])

y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# [[1.00000000e+00 9.99438742e-02 9.98877799e-03 9.98317171e-04
#   9.97756858e-05 9.97196859e-06]
#  [1.00000000e+00 9.85997254e-01 9.72190586e-01 9.58577248e-01
#   9.45154535e-01 9.31919777e-01]
#  [1.00000000e+00 1.39591040e+00 1.94856584e+00 2.72002332e+00
#   3.79690883e+00 5.30014452e+00]
#  [1.00000000e+00 1.44754036e+00 2.09537311e+00 3.03313715e+00
#   4.39058845e+00 6.35555401e+00]
#  [1.00000000e+00 4.26770020e+00 1.82132650e+01 7.77287544e+01
#   3.31723021e+02 1.41569440e+03]
#  [1.00000000e+00 4.68322337e+00 2.19325812e+01 1.02715177e+02
#   4.81038116e+02 2.25280895e+03]
#  [1.00000000e+00 5.42795763e+00 2.94627240e+01 1.59922418e+02
#   8.68052107e+02 4.71175006e+03]
#  [1.00000000e+00 6.45394236e+00 4.16533720e+01 2.68828462e+02
#   1.73500340e+03 1.11976119e+04]
#  [1.00000000e+00 7.93669447e+00 6.29911191e+01 4.99941267e+02
#   3.96788109e+03 3.14918599e+04]
#  [1.00000000e+00 9.68714704e+00 9.38408177e+01 9.09049799e+02
#   8.80609907e+03 8.53059765e+04]]
# Mean Squared Error: 3.9165
# R-squared: 0.6721

# %%
degree = 8
V = np.vander(x, N=degree+1, increasing=True)

print(V)

# V.T * V
VT_V = np.dot(V.T, V)
# V.T * y
VT_y = np.dot(V.T, y)
# Solve for a (coefficients)
coefficients = np.linalg.solve(VT_V, VT_y)

polynomial = np.poly1d(coefficients[::-1])

y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# [[1.00000000e+00 9.99438742e-02 9.98877799e-03 9.98317171e-04
#   9.97756858e-05 9.97196859e-06 9.96637174e-07 9.96077803e-08
#   9.95518747e-09]
#  [1.00000000e+00 9.85997254e-01 9.72190586e-01 9.58577248e-01
#   9.45154535e-01 9.31919777e-01 9.18870341e-01 9.06003634e-01
#   8.93317095e-01]
#  [1.00000000e+00 1.39591040e+00 1.94856584e+00 2.72002332e+00
#   3.79690883e+00 5.30014452e+00 7.39852684e+00 1.03276806e+01
#   1.44165167e+01]
#  [1.00000000e+00 1.44754036e+00 2.09537311e+00 3.03313715e+00
#   4.39058845e+00 6.35555401e+00 9.19992096e+00 1.33172569e+01
#   1.92772670e+01]
#  [1.00000000e+00 4.26770020e+00 1.82132650e+01 7.77287544e+01
#   3.31723021e+02 1.41569440e+03 6.04175927e+03 2.57844172e+04
#   1.10040162e+05]
#  [1.00000000e+00 4.68322337e+00 2.19325812e+01 1.02715177e+02
#   4.81038116e+02 2.25280895e+03 1.05504075e+04 4.94099150e+04
#   2.31397669e+05]
#  [1.00000000e+00 5.42795763e+00 2.94627240e+01 1.59922418e+02
#   8.68052107e+02 4.71175006e+03 2.55751797e+04 1.38820992e+05
#   7.53514460e+05]
#  [1.00000000e+00 6.45394236e+00 4.16533720e+01 2.68828462e+02
#   1.73500340e+03 1.11976119e+04 7.22687419e+04 4.66418295e+05
#   3.01023679e+06]
#  [1.00000000e+00 7.93669447e+00 6.29911191e+01 4.99941267e+02
#   3.96788109e+03 3.14918599e+04 2.49941271e+05 1.98370750e+06
#   1.57440804e+07]
#  [1.00000000e+00 9.68714704e+00 9.38408177e+01 9.09049799e+02
#   8.80609907e+03 8.53059765e+04 8.26371538e+05 8.00518259e+06
#   7.75473808e+07]]
# Mean Squared Error: 0.7175
# R-squared: 0.9399

# %%
degree = 10
V = np.vander(x, N=degree+1, increasing=True)

print(V)

# V.T * V
VT_V = np.dot(V.T, V)
# V.T * y
VT_y = np.dot(V.T, y)
# Solve for a (coefficients)
coefficients = np.linalg.solve(VT_V, VT_y)

polynomial = np.poly1d(coefficients[::-1])

y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# [[1.00000000e+00 9.99438742e-02 9.98877799e-03 9.98317171e-04
#   9.97756858e-05 9.97196859e-06 9.96637174e-07 9.96077803e-08
#   9.95518747e-09 9.94960004e-10 9.94401575e-11]
#  [1.00000000e+00 9.85997254e-01 9.72190586e-01 9.58577248e-01
#   9.45154535e-01 9.31919777e-01 9.18870341e-01 9.06003634e-01
#   8.93317095e-01 8.80808203e-01 8.68474470e-01]
#  [1.00000000e+00 1.39591040e+00 1.94856584e+00 2.72002332e+00
#   3.79690883e+00 5.30014452e+00 7.39852684e+00 1.03276806e+01
#   1.44165167e+01 2.01241655e+01 2.80915319e+01]
#  [1.00000000e+00 1.44754036e+00 2.09537311e+00 3.03313715e+00
#   4.39058845e+00 6.35555401e+00 9.19992096e+00 1.33172569e+01
#   1.92772670e+01 2.79046220e+01 4.03930667e+01]
#  [1.00000000e+00 4.26770020e+00 1.82132650e+01 7.77287544e+01
#   3.31723021e+02 1.41569440e+03 6.04175927e+03 2.57844172e+04
#   1.10040162e+05 4.69618422e+05 2.00419063e+06]
#  [1.00000000e+00 4.68322337e+00 2.19325812e+01 1.02715177e+02
#   4.81038116e+02 2.25280895e+03 1.05504075e+04 4.94099150e+04
#   2.31397669e+05 1.08368697e+06 5.07514815e+06]
#  [1.00000000e+00 5.42795763e+00 2.94627240e+01 1.59922418e+02
#   8.68052107e+02 4.71175006e+03 2.55751797e+04 1.38820992e+05
#   7.53514460e+05 4.09004456e+06 2.22005886e+07]
#  [1.00000000e+00 6.45394236e+00 4.16533720e+01 2.68828462e+02
#   1.73500340e+03 1.11976119e+04 7.22687419e+04 4.66418295e+05
#   3.01023679e+06 1.94278947e+07 1.25386513e+08]
#  [1.00000000e+00 7.93669447e+00 6.29911191e+01 4.99941267e+02
#   3.96788109e+03 3.14918599e+04 2.49941271e+05 1.98370750e+06
#   1.57440804e+07 1.24955956e+08 9.91737241e+08]
#  [1.00000000e+00 9.68714704e+00 9.38408177e+01 9.09049799e+02
#   8.80609907e+03 8.53059765e+04 8.26371538e+05 8.00518259e+06
#   7.75473808e+07 7.51212880e+08 7.27710963e+09]]
# Mean Squared Error: 0.0006
# R-squared: 1.0000

# %%
degree = 12
V = np.vander(x, N=degree+1, increasing=True)

print(V)

# V.T * V
VT_V = np.dot(V.T, V)
# V.T * y
VT_y = np.dot(V.T, y)
# Solve for a (coefficients)
coefficients = np.linalg.solve(VT_V, VT_y)

polynomial = np.poly1d(coefficients[::-1])

y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# [[1.00000000e+00 9.99438742e-02 9.98877799e-03 9.98317171e-04
#   9.97756858e-05 9.97196859e-06 9.96637174e-07 9.96077803e-08
#   9.95518747e-09 9.94960004e-10 9.94401575e-11 9.93843459e-12
#   9.93285656e-13]
#  [1.00000000e+00 9.85997254e-01 9.72190586e-01 9.58577248e-01
#   9.45154535e-01 9.31919777e-01 9.18870341e-01 9.06003634e-01
#   8.93317095e-01 8.80808203e-01 8.68474470e-01 8.56313443e-01
#   8.44322704e-01]
#  [1.00000000e+00 1.39591040e+00 1.94856584e+00 2.72002332e+00
#   3.79690883e+00 5.30014452e+00 7.39852684e+00 1.03276806e+01
#   1.44165167e+01 2.01241655e+01 2.80915319e+01 3.92132615e+01
#   5.47381995e+01]
#  [1.00000000e+00 1.44754036e+00 2.09537311e+00 3.03313715e+00
#   4.39058845e+00 6.35555401e+00 9.19992096e+00 1.33172569e+01
#   1.92772670e+01 2.79046220e+01 4.03930667e+01 5.84705945e+01
#   8.46385457e+01]
#  [1.00000000e+00 4.26770020e+00 1.82132650e+01 7.77287544e+01
#   3.31723021e+02 1.41569440e+03 6.04175927e+03 2.57844172e+04
#   1.10040162e+05 4.69618422e+05 2.00419063e+06 8.55328476e+06
#   3.65028550e+07]
#  [1.00000000e+00 4.68322337e+00 2.19325812e+01 1.02715177e+02
#   4.81038116e+02 2.25280895e+03 1.05504075e+04 4.94099150e+04
#   2.31397669e+05 1.08368697e+06 5.07514815e+06 2.37680524e+07
#   1.11311099e+08]
#  [1.00000000e+00 5.42795763e+00 2.94627240e+01 1.59922418e+02
#   8.68052107e+02 4.71175006e+03 2.55751797e+04 1.38820992e+05
#   7.53514460e+05 4.09004456e+06 2.22005886e+07 1.20503854e+08
#   6.54089815e+08]
#  [1.00000000e+00 6.45394236e+00 4.16533720e+01 2.68828462e+02
#   1.73500340e+03 1.11976119e+04 7.22687419e+04 4.66418295e+05
#   3.01023679e+06 1.94278947e+07 1.25386513e+08 8.09237326e+08
#   5.22277105e+09]
#  [1.00000000e+00 7.93669447e+00 6.29911191e+01 4.99941267e+02
#   3.96788109e+03 3.14918599e+04 2.49941271e+05 1.98370750e+06
#   1.57440804e+07 1.24955956e+08 9.91737241e+08 7.87111548e+09
#   6.24706387e+10]
#  [1.00000000e+00 9.68714704e+00 9.38408177e+01 9.09049799e+02
#   8.80609907e+03 8.53059765e+04 8.26371538e+05 8.00518259e+06
#   7.75473808e+07 7.51212880e+08 7.27710963e+09 7.04944310e+10
#   6.82889918e+11]]
# Mean Squared Error: 0.0000
# R-squared: 1.0000

# %% [markdown]
# citation: I search up in Google Gemini why my polynomial fit using the Vandermonde Matrix was not fitting my graph and found that np.poly1d reads coefficents in decreasing order, so I had to reverse the array for my code to work.
