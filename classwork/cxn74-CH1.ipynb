# %% [markdown]
# 02/03/2026

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(1, 100, 1000)
y = np.linspace(1, 100, 1000)
z = 1/x

plt.subplot(2, 2, 1)
plt.plot(x, z, 'r')

plt.subplot(2, 2, 2)
plt.plot(x, x**2, 'b')

plt.subplot(2, 2, 3)
plt.scatter(x, y, 'g')

plt.subplot(2, 2, 4)
plt.hist(x, 100)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-0df33df533e6> in <module>
#       9
#      10 plt.subplot(2, 2, 3)
# ---> 11 plt.scatter(x, 50, 'g')
#      12
#      13 plt.subplot(2, 2, 4)
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2834         vmin=None, vmax=None, alpha=None, linewidths=None, verts=None,
#    2835         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2836     __ret = gca().scatter(
#    2837         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2838         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %% [markdown]
# #####
